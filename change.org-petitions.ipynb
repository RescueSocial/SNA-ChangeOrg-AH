# %%
import pandas as pd
import requests
from time import sleep
pd.set_option('display.max_columns', None)
from get_petitions import search_petitions

# %%
pd.DataFrame(search_petitions('Amber Heard'))
# Out:
#          _index      _type                    _id    _score  \
# 0  petitions-en  petitions  20569720::Amber Heard  7.176912
# 1  petitions-en  petitions  26062476::Amber Heard  7.176912
# 2  petitions-en  petitions  33340436::Amber Heard  6.774588
# 3  petitions-en  petitions  29615065::Amber Heard  6.723067
# 4  petitions-en  petitions  14451136::Amber Heard  6.719161
# 5  petitions-en  petitions  31208552::Amber Heard  6.682460
# 6  petitions-en  petitions  22874214::Amber Heard  6.650198
# 7  petitions-en  petitions  25704328::Amber Heard  6.527620
# 8  petitions-en  petitions  33174933::Amber Heard  6.275792
# 9  petitions-en  petitions  25752458::Amber Heard  6.265967
#
#    _source.total_signature_count _source.created_locale _source.first_name  \
# 0                         200008                  en-US              Linda
# 1                         200005                  en-US           Kasandra
# 2                          20003                  en-US               Tine
# ...
